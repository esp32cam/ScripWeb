# %%
import pandas as pd
from datetime import datetime, timedelta

def get_data():
    # โหลดข้อมูลรับรอง JSON จากไฟล์ที่คุณดาวน์โหลด
    credentials = Credentials.from_service_account_file('keys.json', scopes=['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])

    # ตั้งค่าการเชื่อมต่อ gspread ด้วยข้อมูลรับรอง
    gc = gspread.service_account(filename='keys.json')

    # เปิดสเปรดชีตของ Google Sheets โดยใช้ชื่อหรือ URL
    spreadsheet = gc.open('stores_shopee')
 
    # เลือกชีตที่ต้องการใน Google Sheets
    worksheet = spreadsheet.worksheet('ชีต1')

    # อ่านข้อมูลจากชีตเป็นรายการของดิกชันนารี
    data = worksheet.get_all_records()

    # สร้าง DataFrame จากข้อมูล
    df = pd.DataFrame(data)

    return df

# %%
df = get_data()

# %%
df
# Out:
#                      Brand Name  \
# 0                       ABOVE.G
# 1                      Acne-Aid
# 2       Acne Aid and Spectraban
# 3       Acnoc Thailand_Official
# 4               Adella Thailand
# ...                         ...
# 4285                       YOYA
# 4286                    Zequenz
# 4287              555 paperplus
# 4288                639 Packing
# 4289  แม่ไม้เพลงไทย เพลงต้นฉบับ
#
#                                              Brand Link  Vm
# 0                          https://shopee.co.th/above.g   1
# 1                https://shopee.co.th/sensodynethailand   2
# 2          https://shopee.co.th/acne_aid_and_spectraban   3
# 3                   https://shopee.co.th/acnoc_thailand   4
# 4          https://shopee.co.th/adellathailand.official   1
# ...                                                 ...  ..
# 4285  https://shopee.co.th/yoyastationery_official_shop   2
# 4286                       https://shopee.co.th/zequenz   3
# 4287     https://shopee.co.th/555paperplus_officialshop   4
# 4288       https://shopee.co.th/639express_officialshop   1
# 4289               https://shopee.co.th/maemaiplengthai   2
#
# [4290 rows x 3 columns]

# %%
! pip install gspread google-auth google-auth-oauthlib google-auth-httplib2
! pip install --upgrade certifi
! pip install mysql-connector-python
! pip install google-auth


import pandas as pd
pd.options.display.float_format = "{:,.3f}".format

import numpy as np
import datetime
import mysql.connector
import yfinance as yf
import requests

import warnings
warnings.filterwarnings('ignore')
from functools import lru_cache

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'tahoma'
import matplotlib.ticker as ticker

import gspread
from google.oauth2.service_account import Credentials
#import gspread_dataframe as gd
# Out:
# Requirement already satisfied: gspread in c:\users\arzo4\anaconda3\lib\site-packages (5.11.3)
# Requirement already satisfied: google-auth in c:\users\arzo4\anaconda3\lib\site-packages (2.17.3)
# Requirement already satisfied: google-auth-oauthlib in c:\users\arzo4\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\arzo4\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: httplib2>=0.15.0 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\arzo4\anaconda3\lib\site-packages (from httplib2>=0.15.0->google-auth-httplib2) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\arzo4\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: requests>=2.0.0 in c:\users\arzo4\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.30.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\arzo4\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arzo4\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arzo4\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arzo4\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arzo4\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2022.12.7)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# Requirement already satisfied: certifi in c:\users\arzo4\anaconda3\lib\site-packages (2022.12.7)
# Collecting certifi
#   Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#      -------------------------------------- 162.5/162.5 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: certifi
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.12.7
#     Uninstalling certifi-2022.12.7:
#       Successfully uninstalled certifi-2022.12.7
# Successfully installed certifi-2023.11.17
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.27 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.27 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.27 requires requests==2.28.1, but you have requests 2.30.0 which is incompatible.
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# Requirement already satisfied: mysql-connector-python in c:\users\arzo4\anaconda3\lib\site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in c:\users\arzo4\anaconda3\lib\site-packages (from mysql-connector-python) (4.21.12)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# Requirement already satisfied: google-auth in c:\users\arzo4\anaconda3\lib\site-packages (2.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\arzo4\anaconda3\lib\site-packages (from google-auth) (1.16.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\arzo4\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\arzo4\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arzo4\anaconda3\lib\site-packages)
